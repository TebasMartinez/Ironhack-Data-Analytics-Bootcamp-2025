# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/dipalira/Melbourne-Housing-Data-Kaggle/master/Data/Melbourne_housing_FULL.csv")
df
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis   3/09/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %% [markdown]
# # 1

# %%
pd.to_numeric(df["Price"])
# Out:
# 0              NaN
# 1        1480000.0
# 2        1035000.0
# 3              NaN
# 4        1465000.0
#            ...
# 34852    1480000.0
# 34853     888000.0
# 34854     705000.0
# 34855    1140000.0
# 34856    1020000.0
# Name: Price, Length: 34857, dtype: float64

# %%
df.dropna(subset=["Price"], inplace=True)

# %%
df["Price"] = df["Price"].astype(int)

# %%
df
# Out:
#            Suburb           Address  Rooms Type    Price Method  \
# 1      Abbotsford      85 Turner St      2    h  1480000      S
# 2      Abbotsford   25 Bloomburg St      2    h  1035000      S
# 4      Abbotsford      5 Charles St      3    h  1465000     SP
# 5      Abbotsford  40 Federation La      3    h   850000     PI
# 6      Abbotsford       55a Park St      4    h  1600000     VB
# ...           ...               ...    ...  ...      ...    ...
# 34852  Yarraville       13 Burns St      4    h  1480000     PI
# 34853  Yarraville     29A Murray St      2    h   888000     SP
# 34854  Yarraville    147A Severn St      2    t   705000      S
# 34855  Yarraville  12/37 Stephen St      3    h  1140000     SP
# 34856  Yarraville  3 Tarrengower St      2    h  1020000     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 1             Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
34857 - 27247
# Out:
# 7610

# %%
(7610 * 100) / 34857
# Out:
# 21.83205668875692

# %% [markdown]
# # 2

# %%
df["Type"].value_counts(normalize=True)
# Out:
# Type
# h    0.677946
# u    0.216868
# t    0.105186
# Name: proportion, dtype: float64

# %% [markdown]
# # 4

# %%
df.groupby("Rooms")["Price"].mean().astype(int)
# Out:
# Rooms
# 1      432888
# 2      759484
# 3     1028499
# 4     1369596
# 5     1818862
# 6     1882613
# 7     1791675
# 8     1716858
# 9     1380000
# 10    2018000
# 12    2705000
# 16    5000000
# Name: Price, dtype: int64

# %% [markdown]
# # 5

# %%
correlation = df["Price"].corr(df["Rooms"], method='spearman')
correlation
# Out:
# 0.5042971590926004

# %% [markdown]
# # 6

# %%
sns.scatterplot(data=df, x="Distance", y="Price")
# Out:
# <Axes: xlabel='Distance', ylabel='Price'>

# %%
# Pearson
correlation = df["Price"].corr(df["Distance"])
correlation
# Out:
# -0.2113843427915831

# %%
# Spearman
correlation = df["Price"].corr(df["Distance"], method='spearman')
correlation
# Out:
# -0.18809341092744206

# %% [markdown]
# # 7

# %%
sns.scatterplot(data=df, x="BuildingArea", y="Price")
# Out:
# <Axes: xlabel='BuildingArea', ylabel='Price'>

# %%
# Pearson
correlation = df["Price"].corr(df["BuildingArea"])
correlation
# Out:
# 0.10075363947310155

# %%
# Spearman
correlation = df["Price"].corr(df["BuildingArea"], method='spearman')
correlation
# Out:
# 0.5553540450665009

# %% [markdown]
# # 8

# %%
frequency_table = df['BuildingArea'].value_counts()

sns.barplot(x=frequency_table.index, y=frequency_table.values , bins=7)
plt.show();
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[111], line 3
#       1 frequency_table = df['BuildingArea'].value_counts()
# ----> 3 sns.barplot(x=frequency_table.index, y=frequency_table.values , bins=7)
#       4 plt.show()
#
# File /opt/anaconda3/lib/python3.12/site-packages/seaborn/categorical.py:2371, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2369 saturation = saturation if fill else 1
#    2370 p.map_hue(palette=palette, order=hue_order, norm=hue_norm, saturation=saturation)
# -> 2371 color = _default_color(ax.bar, hue, color, kwargs, saturation=saturation)
# ...

# %% [markdown]
# # 9

# %%
sns.boxplot(data = df["Price"], color="lightblue")
plt.show();

# %%
def tukeys_test_outliers(data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    
    # Define bounds for the outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Identify the outliers
    outliers = data[(data < lower_bound) | (data > upper_bound)]
    
    return outliers

percentage_outliers = (len(tukeys_test_outliers(df["Price"])) * 100) / len(df["Price"])
percentage_outliers
# Out:
# 4.69042463390465

# %% [markdown]
# # 10

# %%
import statsmodels.api as sm

sm.qqplot(df['Price'], line='s');

# %% [markdown]
# # 11

# %%
from scipy import stats
stats.kstest(df["Price"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/3j/f7d6p9t136x34vdmdy30wrrc0000gn/T/ipykernel_13645/2131930540.py in ?()
#       1 from scipy import stats
# ----> 2 stats.kstest(df["Price"])
#
# /opt/anaconda3/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py in ?(_no_deco, *args, **kwds)
#     430                 # Future refactoring idea: no need for callable n_samples.
#     431                 # Just replace `n_samples` and `kwd_samples` with a single
#     432                 # list of the names of all samples, and treat all of them
#     433                 # as `kwd_samples` are treated below.
# --> 434                 n_samp = n_samples(kwds)
#     435             else:
#     436                 n_samp = n_samples or len(args)
#     437
#
# /opt/anaconda3/lib/python3.12/site-packages/scipy/stats/_stats_py.py in ?(kwargs)
# ...

# %% [markdown]
# # 12

# %%
sns.boxplot(data=df, x='Type', y='Price', palette="coolwarm")
plt.show();
# Out:
# /var/folders/3j/f7d6p9t136x34vdmdy30wrrc0000gn/T/ipykernel_13645/651145347.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Type', y='Price', palette="coolwarm")

# %% [markdown]
# # 13

# %%
df.groupby("Regionname")["Price"].median().sort_values()
# Out:
# Regionname
# Western Victoria               412125.0
# Northern Victoria              565000.0
# Eastern Victoria               679000.0
# Western Metropolitan           750000.0
# Northern Metropolitan          752500.0
# South-Eastern Metropolitan     811250.0
# Eastern Metropolitan          1015000.0
# Southern Metropolitan         1250000.0
# Name: Price, dtype: float64

# %% [markdown]
# # 14

# %%
from scipy.stats import chi2_contingency

crosstab_result = pd.crosstab(df['Regionname'], df['Price'])

chi2_statistic, chi2_p_value, _, _ = chi2_contingency(crosstab_result)

chi2_p_value
# Out:
# 1.804092622742568e-144

# %%
from scipy.stats.contingency import association

association(crosstab_result, method="cramer")
# Out:
# 0.3668031316595495

# %% [markdown]
# # 15

# %%
import datetime

# %%
df["Date"] = pd.to_datetime(df["Date"], format="%d/%m/%Y")
df["Year"] = df["Date"].dt.year
df["Year"]
# Out:
# 1        2016
# 2        2016
# 4        2017
# 5        2017
# 6        2016
#          ...
# 34852    2018
# 34853    2018
# 34854    2018
# 34855    2018
# 34856    2018
# Name: Year, Length: 27247, dtype: int32

# %%
df.groupby("Year")["Price"].median().sort_values(ascending=True)
# Out:
# Year
# 2018    836500.0
# 2017    875000.0
# 2016    885000.0
# Name: Price, dtype: float64

# %%
885000.0 - 836500.0
# Out:
# 48500.0

# %%
(48500.0 * 100) / 836500.0
# Out:
# 5.797967722653915

# %% [markdown]
# # 16

# %%
df["Month"] = df["Date"].dt.month
df["Month"].value_counts().sort_values()
# Out:
# Month
# 1      649
# 4     1206
# 12    1490
# 2     2067
# 8     2324
# 7     2359
# 3     2362
# 6     2425
# 5     2620
# 10    3118
# 9     3219
# 11    3408
# Name: count, dtype: int64
